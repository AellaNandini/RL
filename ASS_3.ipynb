# %% [markdown]
# <a href="https://colab.research.google.com/github/AellaNandini/RL/blob/main/ASS_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym


# ---------------------------------------------------------
# RANDOM AGENT FUNCTION
# ---------------------------------------------------------

def random_agent(environment_name):

    print("\n" + "=" * 60)
    print("ENVIRONMENT:", environment_name)
    print("=" * 60)

    # 1. Create the environment
    env = gym.make(environment_name)

    # 2. Reset the environment
    state, info = env.reset()

    # Variables
    total_reward = 0
    steps = 0

    # 3. Observe initial state
    print("\nInitial State:", state)
    print("Action Space:", env.action_space)

    # 4-8. Select random action and interact with environment
    while True:

        # 5. Select an action randomly
        action = env.action_space.sample()

        # 6. Execute the action
        next_state, reward, terminated, truncated, info = env.step(action)

        # 7. Observe next state and reward
        steps += 1
        total_reward += reward

        print("\nStep:", steps)
        print("Current State:", state)
        print("Random Action:", action)
        print("Reward:", reward)
        print("Next State:", next_state)

        # Update state
        state = next_state

        # 8. Check whether episode has terminated
        if terminated or truncated:
            break

    # 9. Calculate average reward
    average_reward = total_reward / steps

    # Display results
    print("\n" + "-" * 60)
    print("EPISODE COMPLETED")
    print("-" * 60)
    print("Environment       :", environment_name)
    print("Total Steps       :", steps)
    print("Total Reward      :", total_reward)
    print("Average Reward    :", round(average_reward, 4))

    # Close environment
    env.close()


# ---------------------------------------------------------
# RUN RANDOM AGENT FOR CARTPOLE
# ---------------------------------------------------------

random_agent("CartPole-v1")


# ---------------------------------------------------------
# RUN RANDOM AGENT FOR MOUNTAINCAR
# ---------------------------------------------------------

random_agent("MountainCar-v0")


# ---------------------------------------------------------
# RUN RANDOM AGENT FOR FROZENLAKE
# ---------------------------------------------------------

random_agent("FrozenLake-v1")
# Out:
# ============================================================
# ENVIRONMENT: CartPole-v1
# ============================================================
#
# Initial State: [ 0.03192061  0.00980526 -0.03290623 -0.01566811]
# Action Space: Discrete(2)
#
# Step: 1
# Current State: [ 0.03192061  0.00980526 -0.03290623 -0.01566811]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.03211671 -0.1848297  -0.03321959  0.2664536 ]
#
# Step: 2
# Current State: [ 0.03211671 -0.1848297  -0.03321959  0.2664536 ]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.02842012  0.01075023 -0.02789052 -0.03651921]
#
# Step: 3
# Current State: [ 0.02842012  0.01075023 -0.02789052 -0.03651921]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.02863512 -0.18396088 -0.02862091  0.24723513]
#
# Step: 4
# Current State: [ 0.02863512 -0.18396088 -0.02862091  0.24723513]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.02495591 -0.37866265 -0.02367621  0.53075475]
#
# Step: 5
# Current State: [ 0.02495591 -0.37866265 -0.02367621  0.53075475]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01738265 -0.18321578 -0.01306111  0.23070648]
#
# Step: 6
# Current State: [ 0.01738265 -0.18321578 -0.01306111  0.23070648]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01371834  0.01209034 -0.00844698 -0.06606758]
#
# Step: 7
# Current State: [ 0.01371834  0.01209034 -0.00844698 -0.06606758]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01396014  0.20733237 -0.00976833 -0.36140355]
#
# Step: 8
# Current State: [ 0.01396014  0.20733237 -0.00976833 -0.36140355]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.01810679  0.01235062 -0.0169964  -0.07181673]
#
# Step: 9
# Current State: [ 0.01810679  0.01235062 -0.0169964  -0.07181673]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.0183538  -0.1825236  -0.01843274  0.21545567]
#
# Step: 10
# Current State: [ 0.0183538  -0.1825236  -0.01843274  0.21545567]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01470333  0.01285696 -0.01412362 -0.0829843 ]
#
# Step: 11
# Current State: [ 0.01470333  0.01285696 -0.01412362 -0.0829843 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.01496047 -0.1820597  -0.01578331  0.20520934]
#
# Step: 12
# Current State: [ 0.01496047 -0.1820597  -0.01578331  0.20520934]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01131928  0.01328435 -0.01167912 -0.09241035]
#
# Step: 13
# Current State: [ 0.01131928  0.01328435 -0.01167912 -0.09241035]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01158496  0.20857173 -0.01352733 -0.38875502]
#
# Step: 14
# Current State: [ 0.01158496  0.20857173 -0.01352733 -0.38875502]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.0157564   0.01364438 -0.02130243 -0.10036766]
#
# Step: 15
# Current State: [ 0.0157564   0.01364438 -0.02130243 -0.10036766]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.01602929 -0.1811659  -0.02330978  0.18551901]
#
# Step: 16
# Current State: [ 0.01602929 -0.1811659  -0.02330978  0.18551901]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01240597  0.01428168 -0.0195994  -0.11442516]
#
# Step: 17
# Current State: [ 0.01240597  0.01428168 -0.0195994  -0.11442516]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.0126916  -0.18055403 -0.02188791  0.17201042]
#
# Step: 18
# Current State: [ 0.0126916  -0.18055403 -0.02188791  0.17201042]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.00908052  0.01487424 -0.0184477  -0.1274963 ]
#
# Step: 19
# Current State: [ 0.00908052  0.01487424 -0.0184477  -0.1274963 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.00937801 -0.17997865 -0.02099762  0.15930998]
#
# Step: 20
# Current State: [ 0.00937801 -0.17997865 -0.02099762  0.15930998]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.00577843  0.01543753 -0.01781143 -0.13992251]
#
# Step: 21
# Current State: [ 0.00577843  0.01543753 -0.01781143 -0.13992251]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.00608718  0.21080999 -0.02060988 -0.438171  ]
#
# Step: 22
# Current State: [ 0.00608718  0.21080999 -0.02060988 -0.438171  ]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01030338  0.40621752 -0.0293733  -0.7372789 ]
#
# Step: 23
# Current State: [ 0.01030338  0.40621752 -0.0293733  -0.7372789 ]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.01842773  0.60173255 -0.04411887 -1.0390595 ]
#
# Step: 24
# Current State: [ 0.01842773  0.60173255 -0.04411887 -1.0390595 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.03046238  0.40722373 -0.06490006 -0.7605469 ]
#
# Step: 25
# Current State: [ 0.03046238  0.40722373 -0.06490006 -0.7605469 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.03860686  0.21305309 -0.080111   -0.48897135]
#
# Step: 26
# Current State: [ 0.03860686  0.21305309 -0.080111   -0.48897135]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.04286792  0.40920848 -0.08989043 -0.8057882 ]
#
# Step: 27
# Current State: [ 0.04286792  0.40920848 -0.08989043 -0.8057882 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.05105209  0.21542615 -0.10600619 -0.5426805 ]
#
# Step: 28
# Current State: [ 0.05105209  0.21542615 -0.10600619 -0.5426805 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.05536061  0.02194121 -0.1168598  -0.28518972]
#
# Step: 29
# Current State: [ 0.05536061  0.02194121 -0.1168598  -0.28518972]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.05579944  0.21851909 -0.12256359 -0.6123241 ]
#
# Step: 30
# Current State: [ 0.05579944  0.21851909 -0.12256359 -0.6123241 ]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.06016982  0.4151215  -0.13481008 -0.94095904]
#
# Step: 31
# Current State: [ 0.06016982  0.4151215  -0.13481008 -0.94095904]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.06847225  0.22204867 -0.15362926 -0.6934917 ]
#
# Step: 32
# Current State: [ 0.06847225  0.22204867 -0.15362926 -0.6934917 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.07291322  0.02935386 -0.1674991  -0.45284328]
#
# Step: 33
# Current State: [ 0.07291322  0.02935386 -0.1674991  -0.45284328]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.0735003  -0.16305263 -0.17655596 -0.21728748]
#
# Step: 34
# Current State: [ 0.0735003  -0.16305263 -0.17655596 -0.21728748]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.07023925 -0.355269   -0.1809017   0.01491673]
#
# Step: 35
# Current State: [ 0.07023925 -0.355269   -0.1809017   0.01491673]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.06313387 -0.5473978  -0.18060337  0.2455116 ]
#
# Step: 36
# Current State: [ 0.06313387 -0.5473978  -0.18060337  0.2455116 ]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.05218591 -0.35021773 -0.17569314 -0.09825711]
#
# Step: 37
# Current State: [ 0.05218591 -0.35021773 -0.17569314 -0.09825711]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.04518156 -0.15306999 -0.17765829 -0.44081473]
#
# Step: 38
# Current State: [ 0.04518156 -0.15306999 -0.17765829 -0.44081473]
# Random Action: 1
# Reward: 1.0
# Next State: [ 0.04212015  0.04406257 -0.18647458 -0.7838165 ]
#
# Step: 39
# Current State: [ 0.04212015  0.04406257 -0.18647458 -0.7838165 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.04300141 -0.14807454 -0.20215091 -0.5551136 ]
#
# Step: 40
# Current State: [ 0.04300141 -0.14807454 -0.20215091 -0.5551136 ]
# Random Action: 0
# Reward: 1.0
# Next State: [ 0.04003992 -0.33987033 -0.21325319 -0.33230662]
#
# ------------------------------------------------------------
# EPISODE COMPLETED
# ------------------------------------------------------------
# Environment       : CartPole-v1
# Total Steps       : 40
# Total Reward      : 40.0
# Average Reward    : 1.0
#
# ============================================================
# ENVIRONMENT: MountainCar-v0
# ============================================================
#
# Initial State: [-0.5740253  0.       ]
# Action Space: Discrete(3)
#
# Step: 1
# Current State: [-0.5740253  0.       ]
# Random Action: 1
# Reward: -1.0
# Next State: [-5.7364851e-01  3.7675776e-04]
#
# Step: 2
# Current State: [-5.7364851e-01  3.7675776e-04]
# Random Action: 0
# Reward: -1.0
# Next State: [-5.7389778e-01 -2.4927812e-04]
#
# Step: 3
# Current State: [-5.7389778e-01 -2.4927812e-04]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5747712  -0.00087347]
#
# Step: 4
# Current State: [-0.5747712  -0.00087347]
# Random Action: 2
# Reward: -1.0
# Next State: [-5.7426244e-01  5.0882227e-04]
#
# Step: 5
# Current State: [-5.7426244e-01  5.0882227e-04]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.57237506  0.00188734]
#
# Step: 6
# Current State: [-0.57237506  0.00188734]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5691232   0.00325186]
#
# Step: 7
# Current State: [-0.5691232   0.00325186]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.564531    0.00459223]
#
# Step: 8
# Current State: [-0.564531    0.00459223]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.55863255  0.00589845]
#
# Step: 9
# Current State: [-0.55863255  0.00589845]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5534718   0.00516072]
#
# Step: 10
# Current State: [-0.5534718   0.00516072]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5470874   0.00638447]
#
# Step: 11
# Current State: [-0.5470874   0.00638447]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5395269   0.00756049]
#
# Step: 12
# Current State: [-0.5395269   0.00756049]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.53084695  0.0086799 ]
#
# Step: 13
# Current State: [-0.53084695  0.0086799 ]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.52111274  0.00973426]
#
# Step: 14
# Current State: [-0.52111274  0.00973426]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.5113971   0.00971561]
#
# Step: 15
# Current State: [-0.5113971   0.00971561]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.50077295  0.01062412]
#
# Step: 16
# Current State: [-0.50077295  0.01062412]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.4903199   0.01045306]
#
# Step: 17
# Current State: [-0.4903199   0.01045306]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.48111603  0.00920389]
#
# Step: 18
# Current State: [-0.48111603  0.00920389]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.4712299   0.00988613]
#
# Step: 19
# Current State: [-0.4712299   0.00988613]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.46273494  0.00849497]
#
# Step: 20
# Current State: [-0.46273494  0.00849497]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.4536939   0.00904103]
#
# Step: 21
# Current State: [-0.4536939   0.00904103]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.44417334  0.00952058]
#
# Step: 22
# Current State: [-0.44417334  0.00952058]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.4342428   0.00993051]
#
# Step: 23
# Current State: [-0.4342428   0.00993051]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.4259745   0.00826833]
#
# Step: 24
# Current State: [-0.4259745   0.00826833]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.4194279   0.00654657]
#
# Step: 25
# Current State: [-0.4194279   0.00654657]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.41264996  0.00677795]
#
# Step: 26
# Current State: [-0.41264996  0.00677795]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.40668887  0.00596111]
#
# Step: 27
# Current State: [-0.40668887  0.00596111]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.4005867   0.00610215]
#
# Step: 28
# Current State: [-0.4005867   0.00610215]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.39638636  0.00420036]
#
# Step: 29
# Current State: [-0.39638636  0.00420036]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.39211708  0.00426926]
#
# Step: 30
# Current State: [-0.39211708  0.00426926]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.38880858  0.00330852]
#
# Step: 31
# Current State: [-0.38880858  0.00330852]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.38648364  0.00232492]
#
# Step: 32
# Current State: [-0.38648364  0.00232492]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.38515833  0.00132531]
#
# Step: 33
# Current State: [-0.38515833  0.00132531]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.38384172  0.0013166 ]
#
# Step: 34
# Current State: [-0.38384172  0.0013166 ]
# Random Action: 1
# Reward: -1.0
# Next State: [-3.8354287e-01  2.9886534e-04]
#
# Step: 35
# Current State: [-3.8354287e-01  2.9886534e-04]
# Random Action: 2
# Reward: -1.0
# Next State: [-3.8326380e-01  2.7908132e-04]
#
# Step: 36
# Current State: [-3.8326380e-01  2.7908132e-04]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.3840064  -0.00074261]
#
# Step: 37
# Current State: [-0.3840064  -0.00074261]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.3857656  -0.00175922]
#
# Step: 38
# Current State: [-0.3857656  -0.00175922]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.38752937 -0.00176376]
#
# Step: 39
# Current State: [-0.38752937 -0.00176376]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.38928556 -0.00175618]
#
# Step: 40
# Current State: [-0.38928556 -0.00175618]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.39202204 -0.00273649]
#
# Step: 41
# Current State: [-0.39202204 -0.00273649]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.39671993 -0.00469788]
#
# Step: 42
# Current State: [-0.39671993 -0.00469788]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.40234658 -0.00562666]
#
# Step: 43
# Current State: [-0.40234658 -0.00562666]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.40786272 -0.00551613]
#
# Step: 44
# Current State: [-0.40786272 -0.00551613]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.41322955 -0.00536682]
#
# Step: 45
# Current State: [-0.41322955 -0.00536682]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.42040908 -0.00717954]
#
# Step: 46
# Current State: [-0.42040908 -0.00717954]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.42935026 -0.00894116]
#
# Step: 47
# Current State: [-0.42935026 -0.00894116]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.4399889  -0.01063865]
#
# Step: 48
# Current State: [-0.4399889  -0.01063865]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.45224807 -0.01225917]
#
# Step: 49
# Current State: [-0.45224807 -0.01225917]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.46403828 -0.01179022]
#
# Step: 50
# Current State: [-0.46403828 -0.01179022]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.47727284 -0.01323455]
#
# Step: 51
# Current State: [-0.47727284 -0.01323455]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.4918537  -0.01458088]
#
# Step: 52
# Current State: [-0.4918537  -0.01458088]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.50567234 -0.01381861]
#
# Step: 53
# Current State: [-0.50567234 -0.01381861]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5206253  -0.01495299]
#
# Step: 54
# Current State: [-0.5206253  -0.01495299]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.5356006  -0.01497529]
#
# Step: 55
# Current State: [-0.5356006  -0.01497529]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5514859 -0.0158853]
#
# Step: 56
# Current State: [-0.5514859 -0.0158853]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.56816226 -0.01667639]
#
# Step: 57
# Current State: [-0.56816226 -0.01667639]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.58450544 -0.01634315]
#
# Step: 58
# Current State: [-0.58450544 -0.01634315]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.6003943  -0.01588889]
#
# Step: 59
# Current State: [-0.6003943  -0.01588889]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.61571234 -0.01531801]
#
# Step: 60
# Current State: [-0.61571234 -0.01531801]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.63134825 -0.01563592]
#
# Step: 61
# Current State: [-0.63134825 -0.01563592]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.64719003 -0.01584179]
#
# Step: 62
# Current State: [-0.64719003 -0.01584179]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.662126   -0.01493595]
#
# Step: 63
# Current State: [-0.662126   -0.01493595]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.67505264 -0.01292665]
#
# Step: 64
# Current State: [-0.67505264 -0.01292665]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.6868821  -0.01182942]
#
# Step: 65
# Current State: [-0.6868821  -0.01182942]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.69853526 -0.01165319]
#
# Step: 66
# Current State: [-0.69853526 -0.01165319]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.70993584 -0.01140057]
#
# Step: 67
# Current State: [-0.70993584 -0.01140057]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.7200105 -0.0100747]
#
# Step: 68
# Current State: [-0.7200105 -0.0100747]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.72769594 -0.00768539]
#
# Step: 69
# Current State: [-0.72769594 -0.00768539]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7329444  -0.00524853]
#
# Step: 70
# Current State: [-0.7329444  -0.00524853]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.73772407 -0.00477963]
#
# Step: 71
# Current State: [-0.73772407 -0.00477963]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.74000597 -0.00228188]
#
# Step: 72
# Current State: [-0.74000597 -0.00228188]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.7417764  -0.00177047]
#
# Step: 73
# Current State: [-0.7417764  -0.00177047]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.74302495 -0.0012485 ]
#
# Step: 74
# Current State: [-0.74302495 -0.0012485 ]
# Random Action: 0
# Reward: -1.0
# Next State: [-7.43744e-01 -7.19106e-04]
#
# Step: 75
# Current State: [-7.43744e-01 -7.19106e-04]
# Random Action: 0
# Reward: -1.0
# Next State: [-7.4392951e-01 -1.8545336e-04]
#
# Step: 76
# Current State: [-7.4392951e-01 -1.8545336e-04]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.7425802  0.0013493]
#
# Step: 77
# Current State: [-0.7425802  0.0013493]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.73970413  0.00287605]
#
# Step: 78
# Current State: [-0.73970413  0.00287605]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.73631847  0.00338566]
#
# Step: 79
# Current State: [-0.73631847  0.00338566]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.7314435   0.00487495]
#
# Step: 80
# Current State: [-0.7314435   0.00487495]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7241088   0.00733472]
#
# Step: 81
# Current State: [-0.7241088   0.00733472]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.71435934  0.00974949]
#
# Step: 82
# Current State: [-0.71435934  0.00974949]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.70225596  0.01210336]
#
# Step: 83
# Current State: [-0.70225596  0.01210336]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.68787587  0.01438006]
#
# Step: 84
# Current State: [-0.68787587  0.01438006]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.67131305  0.01656286]
#
# Step: 85
# Current State: [-0.67131305  0.01656286]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.6546782   0.01663481]
#
# Step: 86
# Current State: [-0.6546782   0.01663481]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.63608545  0.01859277]
#
# Step: 87
# Current State: [-0.63608545  0.01859277]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.61666495  0.0194205 ]
#
# Step: 88
# Current State: [-0.61666495  0.0194205 ]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5955555   0.02110946]
#
# Step: 89
# Current State: [-0.5955555   0.02110946]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.57391053  0.02164495]
#
# Step: 90
# Current State: [-0.57391053  0.02164495]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5528897   0.02102086]
#
# Step: 91
# Current State: [-0.5528897   0.02102086]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5306494   0.02224026]
#
# Step: 92
# Current State: [-0.5306494   0.02224026]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.5083563   0.02229314]
#
# Step: 93
# Current State: [-0.5083563   0.02229314]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.48517743  0.02317886]
#
# Step: 94
# Current State: [-0.48517743  0.02317886]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.46228608  0.02289134]
#
# Step: 95
# Current State: [-0.46228608  0.02289134]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.438852    0.02343408]
#
# Step: 96
# Current State: [-0.438852    0.02343408]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.4160467  0.0228053]
#
# Step: 97
# Current State: [-0.4160467  0.0228053]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.39303413  0.02301259]
#
# Step: 98
# Current State: [-0.39303413  0.02301259]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.37197593  0.0210582 ]
#
# Step: 99
# Current State: [-0.37197593  0.0210582 ]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.3510161   0.02095984]
#
# Step: 100
# Current State: [-0.3510161   0.02095984]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.33029357  0.02072253]
#
# Step: 101
# Current State: [-0.33029357  0.02072253]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.3119409   0.01835264]
#
# Step: 102
# Current State: [-0.3119409   0.01835264]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.29407117  0.01786975]
#
# Step: 103
# Current State: [-0.29407117  0.01786975]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.27879003  0.01528114]
#
# Step: 104
# Current State: [-0.27879003  0.01528114]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.26618427  0.01260574]
#
# Step: 105
# Current State: [-0.26618427  0.01260574]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.2553229   0.01086138]
#
# Step: 106
# Current State: [-0.2553229   0.01086138]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.2472633  0.0080596]
#
# Step: 107
# Current State: [-0.2472633  0.0080596]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.24204685  0.00521645]
#
# Step: 108
# Current State: [-0.24204685  0.00521645]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.23769976  0.00434709]
#
# Step: 109
# Current State: [-0.23769976  0.00434709]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.2352435   0.00245625]
#
# Step: 110
# Current State: [-0.2352435   0.00245625]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.2346901  0.0005534]
#
# Step: 111
# Current State: [-0.2346901  0.0005534]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.23604223 -0.00135213]
#
# Step: 112
# Current State: [-0.23604223 -0.00135213]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.2392933  -0.00325108]
#
# Step: 113
# Current State: [-0.2392933  -0.00325108]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.2454274  -0.00613409]
#
# Step: 114
# Current State: [-0.2454274  -0.00613409]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.25341392 -0.00798651]
#
# Step: 115
# Current State: [-0.25341392 -0.00798651]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.2622121  -0.00879819]
#
# Step: 116
# Current State: [-0.2622121  -0.00879819]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.27377588 -0.01156376]
#
# Step: 117
# Current State: [-0.27377588 -0.01156376]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.28704277 -0.01326689]
#
# Step: 118
# Current State: [-0.28704277 -0.01326689]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.3009386  -0.01389584]
#
# Step: 119
# Current State: [-0.3009386  -0.01389584]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.31538296 -0.01444435]
#
# Step: 120
# Current State: [-0.31538296 -0.01444435]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.33028933 -0.01490638]
#
# Step: 121
# Current State: [-0.33028933 -0.01490638]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.34556562 -0.01527629]
#
# Step: 122
# Current State: [-0.34556562 -0.01527629]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.36111456 -0.01554895]
#
# Step: 123
# Current State: [-0.36111456 -0.01554895]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.37883446 -0.01771989]
#
# Step: 124
# Current State: [-0.37883446 -0.01771989]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.39760628 -0.01877182]
#
# Step: 125
# Current State: [-0.39760628 -0.01877182]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.4163007  -0.01869442]
#
# Step: 126
# Current State: [-0.4163007  -0.01869442]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.43678603 -0.02048533]
#
# Step: 127
# Current State: [-0.43678603 -0.02048533]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.4569151  -0.02012909]
#
# Step: 128
# Current State: [-0.4569151  -0.02012909]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.476541   -0.01962589]
#
# Step: 129
# Current State: [-0.476541   -0.01962589]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.49751866 -0.02097765]
#
# Step: 130
# Current State: [-0.49751866 -0.02097765]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.5186917  -0.02117305]
#
# Step: 131
# Current State: [-0.5186917  -0.02117305]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5409016  -0.02220985]
#
# Step: 132
# Current State: [-0.5409016  -0.02220985]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5639817  -0.02308014]
#
# Step: 133
# Current State: [-0.5639817  -0.02308014]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.58775973 -0.02377801]
#
# Step: 134
# Current State: [-0.58775973 -0.02377801]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.6120595  -0.02429977]
#
# Step: 135
# Current State: [-0.6120595  -0.02429977]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.63670355 -0.02464407]
#
# Step: 136
# Current State: [-0.63670355 -0.02464407]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.65951556 -0.02281197]
#
# Step: 137
# Current State: [-0.65951556 -0.02281197]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.68233615 -0.02282061]
#
# Step: 138
# Current State: [-0.68233615 -0.02282061]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.70301074 -0.02067457]
#
# Step: 139
# Current State: [-0.70301074 -0.02067457]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7214037  -0.01839301]
#
# Step: 140
# Current State: [-0.7214037  -0.01839301]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.73839873 -0.01699503]
#
# Step: 141
# Current State: [-0.73839873 -0.01699503]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.753892   -0.01549323]
#
# Step: 142
# Current State: [-0.753892   -0.01549323]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7667922  -0.01290019]
#
# Step: 143
# Current State: [-0.7667922  -0.01290019]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.779026  -0.0122338]
#
# Step: 144
# Current State: [-0.779026  -0.0122338]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.7905261  -0.01150015]
#
# Step: 145
# Current State: [-0.7905261  -0.01150015]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.8012315  -0.01070539]
#
# Step: 146
# Current State: [-0.8012315  -0.01070539]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.8090872  -0.00785568]
#
# Step: 147
# Current State: [-0.8090872  -0.00785568]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.8140541  -0.00496685]
#
# Step: 148
# Current State: [-0.8140541  -0.00496685]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.81610787 -0.00205383]
#
# Step: 149
# Current State: [-0.81610787 -0.00205383]
# Random Action: 1
# Reward: -1.0
# Next State: [-8.1623882e-01 -1.3092965e-04]
#
# Step: 150
# Current State: [-8.1623882e-01 -1.3092965e-04]
# Random Action: 0
# Reward: -1.0
# Next State: [-8.154462e-01  7.926004e-04]
#
# Step: 151
# Current State: [-8.154462e-01  7.926004e-04]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.8117339   0.00371233]
#
# Step: 152
# Current State: [-0.8117339   0.00371233]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.8061198  0.0056141]
#
# Step: 153
# Current State: [-0.8061198  0.0056141]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.7986315   0.00748828]
#
# Step: 154
# Current State: [-0.7986315   0.00748828]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7883067   0.01032481]
#
# Step: 155
# Current State: [-0.7883067   0.01032481]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.77619874  0.01210794]
#
# Step: 156
# Current State: [-0.77619874  0.01210794]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7613725   0.01482625]
#
# Step: 157
# Current State: [-0.7613725   0.01482625]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.7439104   0.01746212]
#
# Step: 158
# Current State: [-0.7439104   0.01746212]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.72491366  0.01899676]
#
# Step: 159
# Current State: [-0.72491366  0.01899676]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.70549715  0.01941649]
#
# Step: 160
# Current State: [-0.70549715  0.01941649]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.6857831   0.01971402]
#
# Step: 161
# Current State: [-0.6857831   0.01971402]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.6659001   0.01988298]
#
# Step: 162
# Current State: [-0.6659001   0.01988298]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.645982    0.01991812]
#
# Step: 163
# Current State: [-0.645982    0.01991812]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.6241665   0.02181551]
#
# Step: 164
# Current State: [-0.6241665   0.02181551]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.60260814  0.02155837]
#
# Step: 165
# Current State: [-0.60260814  0.02155837]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5794627   0.02314541]
#
# Step: 166
# Current State: [-0.5794627   0.02314541]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.5569003   0.02256243]
#
# Step: 167
# Current State: [-0.5569003   0.02256243]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5330885   0.02381178]
#
# Step: 168
# Current State: [-0.5330885   0.02381178]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.5082056   0.02488294]
#
# Step: 169
# Current State: [-0.5082056   0.02488294]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.48343804  0.02476753]
#
# Step: 170
# Current State: [-0.48343804  0.02476753]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.45997098  0.02346706]
#
# Step: 171
# Current State: [-0.45997098  0.02346706]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.43597823  0.02399274]
#
# Step: 172
# Current State: [-0.43597823  0.02399274]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.41263512  0.02334313]
#
# Step: 173
# Current State: [-0.41263512  0.02334313]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.38910893  0.02352619]
#
# Step: 174
# Current State: [-0.38910893  0.02352619]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.3655643   0.02354466]
#
# Step: 175
# Current State: [-0.3655643   0.02354466]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.34416097  0.02140331]
#
# Step: 176
# Current State: [-0.34416097  0.02140331]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.3250394   0.01912158]
#
# Step: 177
# Current State: [-0.3250394   0.01912158]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.3063205   0.01871891]
#
# Step: 178
# Current State: [-0.3063205   0.01871891]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.2901182   0.01620229]
#
# Step: 179
# Current State: [-0.2901182   0.01620229]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.27552727  0.0145909 ]
#
# Step: 180
# Current State: [-0.27552727  0.0145909 ]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.26262987  0.01289742]
#
# Step: 181
# Current State: [-0.26262987  0.01289742]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.2524958   0.01013406]
#
# Step: 182
# Current State: [-0.2524958   0.01013406]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.24417815  0.00831765]
#
# Step: 183
# Current State: [-0.24417815  0.00831765]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.23871921  0.00545894]
#
# Step: 184
# Current State: [-0.23871921  0.00545894]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.23614609  0.00257311]
#
# Step: 185
# Current State: [-0.23614609  0.00257311]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.23547143  0.00067466]
#
# Step: 186
# Current State: [-0.23547143  0.00067466]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.23769851 -0.00222707]
#
# Step: 187
# Current State: [-0.23769851 -0.00222707]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.24181643 -0.00411792]
#
# Step: 188
# Current State: [-0.24181643 -0.00411792]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.24880485 -0.00698843]
#
# Step: 189
# Current State: [-0.24880485 -0.00698843]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.25762862 -0.00882375]
#
# Step: 190
# Current State: [-0.25762862 -0.00882375]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.2692421  -0.01161349]
#
# Step: 191
# Current State: [-0.2692421  -0.01161349]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.28158346 -0.01234135]
#
# Step: 192
# Current State: [-0.28158346 -0.01234135]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.2955846  -0.01400115]
#
# Step: 193
# Current State: [-0.2955846  -0.01400115]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.31116557 -0.01558098]
#
# Step: 194
# Current State: [-0.31116557 -0.01558098]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.32923412 -0.01806854]
#
# Step: 195
# Current State: [-0.32923412 -0.01806854]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.3496792  -0.02044507]
#
# Step: 196
# Current State: [-0.3496792  -0.02044507]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.37237027 -0.02269108]
#
# Step: 197
# Current State: [-0.37237027 -0.02269108]
# Random Action: 1
# Reward: -1.0
# Next State: [-0.39615706 -0.02378679]
#
# Step: 198
# Current State: [-0.39615706 -0.02378679]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.42187655 -0.02571948]
#
# Step: 199
# Current State: [-0.42187655 -0.02571948]
# Random Action: 0
# Reward: -1.0
# Next State: [-0.44934714 -0.02747061]
#
# Step: 200
# Current State: [-0.44934714 -0.02747061]
# Random Action: 2
# Reward: -1.0
# Next State: [-0.47637007 -0.02702291]
#
# ------------------------------------------------------------
# EPISODE COMPLETED
# ------------------------------------------------------------
# Environment       : MountainCar-v0
# Total Steps       : 200
# Total Reward      : -200.0
# Average Reward    : -1.0
#
# ============================================================
# ENVIRONMENT: FrozenLake-v1
# ============================================================
#
# Initial State: 0
# Action Space: Discrete(4)
#
# Step: 1
# Current State: 0
# Random Action: 1
# Reward: 0
# Next State: 1
#
# Step: 2
# Current State: 1
# Random Action: 1
# Reward: 0
# Next State: 2
#
# Step: 3
# Current State: 2
# Random Action: 0
# Reward: 0
# Next State: 1
#
# Step: 4
# Current State: 1
# Random Action: 2
# Reward: 0
# Next State: 1
#
# Step: 5
# Current State: 1
# Random Action: 0
# Reward: 0
# Next State: 1
#
# Step: 6
# Current State: 1
# Random Action: 0
# Reward: 0
# Next State: 1
#
# Step: 7
# Current State: 1
# Random Action: 0
# Reward: 0
# Next State: 0
#
# Step: 8
# Current State: 0
# Random Action: 3
# Reward: 0
# Next State: 1
#
# Step: 9
# Current State: 1
# Random Action: 2
# Reward: 0
# Next State: 1
#
# Step: 10
# Current State: 1
# Random Action: 1
# Reward: 0
# Next State: 2
#
# Step: 11
# Current State: 2
# Random Action: 1
# Reward: 0
# Next State: 1
#
# Step: 12
# Current State: 1
# Random Action: 0
# Reward: 0
# Next State: 0
#
# Step: 13
# Current State: 0
# Random Action: 1
# Reward: 0
# Next State: 0
#
# Step: 14
# Current State: 0
# Random Action: 3
# Reward: 0
# Next State: 1
#
# Step: 15
# Current State: 1
# Random Action: 1
# Reward: 0
# Next State: 2
#
# Step: 16
# Current State: 2
# Random Action: 1
# Reward: 0
# Next State: 1
#
# Step: 17
# Current State: 1
# Random Action: 2
# Reward: 0
# Next State: 2
#
# Step: 18
# Current State: 2
# Random Action: 3
# Reward: 0
# Next State: 1
#
# Step: 19
# Current State: 1
# Random Action: 0
# Reward: 0
# Next State: 5
#
# ------------------------------------------------------------
# EPISODE COMPLETED
# ------------------------------------------------------------
# Environment       : FrozenLake-v1
# Total Steps       : 19
# Total Reward      : 0
# Average Reward    : 0.0
